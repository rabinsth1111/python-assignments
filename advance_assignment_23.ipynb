# %% [markdown]
# #### Q1. If you have any, what are your choices for increasing the comparison between different figures on the same graph?
# **Ans:** Matplotlib provides a convenient method called subplots for increasing the comparison between different figures on the same graph. Subplots mean a group of smaller axes (where each axis is a plot) that can exist together within a single figure.

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")

plt.show()

# %% [markdown]
# #### Q2. Can you explain the benefit of compound interest over a higher rate of interest that does not compound after reading this chapter?
# **Ans:**
# Compound interest offers a significant advantage over simple interest, especially when it comes to long-term investments. The key difference lies in how interest is calculated and added to the principal amount.
#
# Here's a brief explanation of the benefits of compound interest over a higher rate of simple interest:
#
# **1. Interest on Interest:**
#
# Simple Interest: With simple interest, you earn interest only on the initial principal amount over time. The interest does not accumulate or "compound" on the interest earned in previous periods.
#
# Compound Interest: In contrast, compound interest allows you to earn interest not just on the initial principal but also on the accumulated interest from previous periods. This compounding effect leads to exponential growth in the total amount over time.
#
#
# **2. Accelerated Growth:**
#
# Simple Interest: The growth of an investment with simple interest is linear. The interest earned remains constant each period, leading to a straight line when graphed over time.
#
# Compound Interest: With compound interest, the growth is exponential. As the interest earned is added to the principal, the total amount increases at an accelerating rate. This compounding effect results in a curved graph, and the total amount grows faster over time.
#
#
# **3. Long-Term Wealth Accumulation:**
#
# Simple Interest: Over an extended period, the impact of a higher simple interest rate diminishes as it only applies to the original principal.
#
# Compound Interest: The compounding effect becomes more pronounced over time. Even if the interest rate is lower, the fact that it compounds on itself can lead to significant wealth accumulation, especially over long investment horizons.

# %% [markdown]
# #### Q3. What is a histogram, exactly? Name a numpy method for creating such a graph ?
# **Ans:** A histogram is a graphical representation of the distribution of a dataset. It is a way to visualize the underlying frequency distribution of a set of continuous or discrete data.
#
# In a histogram, the data is divided into intervals, called bins, and the number of data points falling into each bin is represented by the height of a bar. The bars are usually adjacent and touch each other.
#
# To create a histogram in Python, you can use the numpy.histogram function.
#
# Example:

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generating a random dataset
data = np.random.randn(1000)  # Replace this with your dataset

# Creating a histogram using numpy
hist, bins = np.histogram(data, bins=10, density=False)

# Plotting the histogram
plt.hist(data, bins=10, alpha=0.7, color='blue', edgecolor='black')

# Adding labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram Example')

# Display the plot
plt.show()

# %% [markdown]
# #### Q4. If necessary, how do you change the aspect ratios between the X and Y axes ?
# **Ans:** The Aspect ratio is the ratio of length to width of any plot or image that we want to display.
#
# We can easily adjust the aspect ratio in matplotlib by using the set_aspect method from the axes class.<br/>
# The parameter of this method is a number which is a division of the X-axis with respect to the Y-axis.

# %%
#Example with no fixed aspect ratio
import matplotlib.pyplot as plt
import numpy as np
#Setting the axes.
x = np.arange(1,5,0.2)
y = np.sin(7*x)
#Setting the Dimentions of the Graph
plt.figure(figsize = (5,5))

plt.plot(x,y)
plt.title('plot with undefined aspect ratio')
plt.show()

# %%
#Example setting aspect ratio to 5
import matplotlib.pyplot as plt
import numpy as np
#Setting the axes.
x = np.arange(1,5,0.2)
y = np.sin(7*x)
#Setting the Dimentions of the Graph
plt.figure(figsize = (5,5))
#selecting the current axis
ax = plt.gca()
#sets the ratio to 5
ax.set_aspect(5)
plt.plot(x,y)
plt.title('plot with defined aspect ratio')
plt.show()

# %% [markdown]
# #### Q5. Compare and contrast the three types of array multiplication between two numpy arrays: dot product, outer product, and regular multiplication of two numpy arrays ?
# **Ans:**
#
# **1. Regular Element-wise Multiplication:**
#
# Operation: Multiply corresponding elements of two arrays.
#
# NumPy Operation: * operator.
#
# Example:

# %%
import numpy as np

arr1 = np.array([1, 2, 3])
arr2 = np.array([4, 5, 6])

result = arr1 * arr2

result
# Out:
# array([ 4, 10, 18])

# %% [markdown]
# **2. Dot Product:**
#
# Operation: Sum of the element-wise products of the arrays.
#
# NumPy Operation: numpy.dot() or the @ operator.
#
# Example:

# %%
import numpy as np

arr1 = np.array([1, 2, 3])
arr2 = np.array([4, 5, 6])

result = np.dot(arr1, arr2)
# Alternatively: result = arr1 @ arr2

result
# Out:
# 32

# %% [markdown]
# **3. Outer Product:**
#
# Operation: Create a matrix where each element is the product of elements from the first array with elements from the second array.<br/>
# The outer product creates a matrix where each element Cij is the product of Ai×Bj.
#
# NumPy Operation: numpy.outer().
#
# Example:

# %%
import numpy as np

arr1 = np.array([1, 2, 3])
arr2 = np.array([4, 5, 6])

result = np.outer(arr1, arr2)
result
# Out:
# array([[ 4,  5,  6],
#        [ 8, 10, 12],
#        [12, 15, 18]])

# %% [markdown]
# #### Q6. Before you buy a home, which numpy function will you use to measure your monthly mortgage payment ?
# **Ans:** `np.pmt(rate, nper, pv)` function we will be using in order to calculate monthly mortgage payment before you purchase a house.
# - `rate` = The periodic interest rate
# - `nper` = The number of payment periods
# - `pv` = The total value of the mortgage loan

# %% [markdown]
# #### Q7. Can string data be stored in numpy arrays? If so, list at least one restriction that applies to this data ?
# **Ans:** Yes, numpy array can store the strings. The limitation which imposed on the string data is, whenever we store the data of string dtype then it should should keep in mind that the string which is having the maximum length is the limit.

# %%
# importing numpy as np 
import numpy as np 

# Create the numpy array 
country = np.array(['USA', 'Japan', 'UK', '', 'India', 'China']) 

# Print the array 
print(country)
# Out:
# ['USA' 'Japan' 'UK' '' 'India' 'China']

# %%
# Assign 'New Zealand' at the place of missing value 
country[country == ''] = 'New Zealand' 

# Print the modified array 
print(country)
# Out:
# ['USA' 'Japan' 'UK' 'New Z' 'India' 'China']

# %% [markdown]
# As we can see in the output, ‘New Z’ has been assigned rather than ‘New Zealand’ because of the limitation to the length.
#
# We can overcome this problem by converting string type to object type as shown in example below:

# %%
# importing the numpy library as np 
import numpy as np 

# Create a numpy array 
# set the dtype to object 
country = np.array(['USA', 'Japan', 'UK', '', 'India', 'China'], dtype = 'object') 

# Print the array 
print(country) 

# Assign 'New Zealand' to the missing value 
country[country == ''] = 'New Zealand' 

# Print the array 
print(country)
# Out:
# ['USA' 'Japan' 'UK' '' 'India' 'China']
# ['USA' 'Japan' 'UK' 'New Zealand' 'India' 'China']
